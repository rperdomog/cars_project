# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('vehicles_us.csv')
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14852 entries, 5 to 51515
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         14852 non-null  int64
#  1   model_year    14852 non-null  float64
#  2   model         14852 non-null  object
#  3   condition     14852 non-null  object
#  4   cylinders     14852 non-null  float64
#  5   fuel          14852 non-null  object
#  6   odometer      14852 non-null  float64
#  7   transmission  14852 non-null  object
#  8   type          14852 non-null  object
#  9   paint_color   14852 non-null  object
#  10  is_4wd        14852 non-null  float64
#  11  date_posted   14852 non-null  object
#  12  days_listed   14852 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 1.6+ MB

# %%
#Brand popularity
df['manufacturer'] = df['model'].str.split(' ').str[0]

brand_counts = df['manufacturer'].value_counts()

top_brands = brand_counts.head(20)
plt.figure(figsize=(12, 6))
plt.bar(top_brands.index, top_brands.values, color='#007F73')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.title('Top 20 Most Popular Car Brands')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate the mean price for each brand
brand_avg_price = df.groupby('manufacturer')['price'].mean().sort_values(ascending=False)

# Plot the average price for each brand
plt.figure(figsize=(12, 6))
plt.bar(brand_avg_price.index, brand_avg_price.values, color='#007F73')
plt.xlabel('Brand')
plt.ylabel('Average Price')
plt.title('Average Price of Each Car Brand')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate the average days listed for each brand
brand_avg_days_listed = df.groupby('manufacturer')['days_listed'].mean().sort_values(ascending=False)

# Plot the average days listed for each brand
plt.figure(figsize=(12, 6))
plt.bar(brand_avg_days_listed.index, brand_avg_days_listed.values, color='#007F73')
plt.xlabel('Brand')
plt.ylabel('Average Days Listed')
plt.title('Average Days Listed per Car Brand')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate the average days listed per brand
avg_days_listed_per_brand = df.groupby('manufacturer')['days_listed'].mean()

# Plot the average days listed per brand
plt.figure(figsize=(12, 6))
plt.bar(avg_days_listed_per_brand.index, avg_days_listed_per_brand.values, color='#007F73')
plt.xlabel('Brand')
plt.ylabel('Average Days Listed')
plt.title('Average Days Listed per Brand')
plt.xticks(rotation=45)
plt.show()

# %%
# Define the price ranges
price_ranges = [0, 5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, float('inf')]
labels = ['<5k', '5k-10k', '10k-15k', '15k-20k', '20k-25k', '25k-30k', '30k-35k', '35k-40k', '40k-45k', '45k-50k', '50k+']

# Create a new column for price range
df['price_range'] = pd.cut(df['price'], bins=price_ranges, labels=labels, right=False)

# Calculate the average days listed per price range
avg_days_listed_per_price_range = df.groupby('price_range')['days_listed'].mean()

# Plot the average days listed per price range
plt.figure(figsize=(12, 6))
plt.bar(avg_days_listed_per_price_range.index, avg_days_listed_per_price_range.values, color='#007F73')
plt.xlabel('Price Range')
plt.ylabel('Average Days Listed')
plt.title('Average Days Listed per Price Range')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/1l/nbw_db6x2rd8s9znb0vfd7qw0000gn/T/ipykernel_72960/2446625072.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_days_listed_per_price_range = df.groupby('price_range')['days_listed'].mean()

# %%
# Calculate the average days listed per car type
avg_days_listed_per_type = df.groupby('type')['days_listed'].mean()

# Plot the average days listed per car type
plt.figure(figsize=(12, 6))
plt.bar(avg_days_listed_per_type.index, avg_days_listed_per_type.values, color='#007F73')
plt.xlabel('Car Type')
plt.ylabel('Average Days Listed')
plt.title('Average Days Listed per Car Type')
plt.xticks(rotation=45)
plt.show()

# %%
# Define the mileage ranges
mileage_ranges = [0, 50000, 100000, 150000, 200000, 250000, float('inf')]
mileage_labels = ['<50k', '50k-100k', '100k-150k', '150k-200k', '200k-250k', '250k+']

# Create a new column for mileage range
df['mileage_range'] = pd.cut(df['odometer'], bins=mileage_ranges, labels=mileage_labels, right=False)

# Calculate the average days listed per mileage range
avg_days_listed_per_mileage_range = df.groupby('mileage_range')['days_listed'].mean()

# Plot the average days listed per mileage range
plt.figure(figsize=(12, 6))
plt.bar(avg_days_listed_per_mileage_range.index, avg_days_listed_per_mileage_range.values, color='#007F73')
plt.xlabel('Mileage Range')
plt.ylabel('Average Days Listed')
plt.title('Average Days Listed per Mileage Range')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/1l/nbw_db6x2rd8s9znb0vfd7qw0000gn/T/ipykernel_72960/1625274671.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_days_listed_per_mileage_range = df.groupby('mileage_range')['days_listed'].mean()

# %%
# Calculate the average price per mileage range
avg_price_per_mileage_range = df.groupby('mileage_range')['price'].mean()

# Plot the average price per mileage range
plt.figure(figsize=(12, 6))
plt.bar(avg_price_per_mileage_range.index, avg_price_per_mileage_range.values, color='#007F73')
plt.xlabel('Mileage Range')
plt.ylabel('Average Price')
plt.title('Average Price per Mileage Range')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/1l/nbw_db6x2rd8s9znb0vfd7qw0000gn/T/ipykernel_72960/3943080130.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_price_per_mileage_range = df.groupby('mileage_range')['price'].mean()

# %%
#Relation between model year and price

plt.figure(figsize=(8, 6))
plt.scatter(df['model_year'], df['price'], alpha=0.5, color="#007F73")
plt.title('Model Year vs Price')
plt.xlabel('Model Year')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
# Price analysis by manufacturer
manufacturer_prices = df.groupby('manufacturer')['price'].mean()
plt.figure(figsize=(12, 6))
plt.bar(manufacturer_prices.index, manufacturer_prices.values, color="#007F73")
plt.title('Average Price of Cars by Manufacturer')
plt.xlabel('Manufacturer')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# Price analysis by fuel type
fuel_prices = df.groupby('fuel')['price'].mean()
plt.figure(figsize=(8, 6))
plt.bar(fuel_prices.index, fuel_prices.values, color="#007F73")
plt.title('Average Price of Cars by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Average Price')
plt.show()

# Price analysis by transmission type
transmission_prices = df.groupby('transmission')['price'].mean()
plt.figure(figsize=(8, 6))
plt.bar(transmission_prices.index, transmission_prices.values, color="#007F73")
plt.title('Average Price of Cars by Transmission Type')
plt.xlabel('Transmission Type')
plt.ylabel('Average Price')
plt.show()
